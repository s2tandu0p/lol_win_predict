# %% [markdown]
# <a href="https://colab.research.google.com/github/s2tandu0p/lol_win_predict/blob/main/Shaohua_Guan_Project_2_Part_3_Core.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #0. LOAD DATA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
ytrain_data = pd.read_csv('/content/drive/MyDrive/Personal/Dojo/data/lol win predict/lol-prediction/lol.y_train.csv')
xtrain_data = pd.read_csv('/content/drive/MyDrive/Personal/Dojo/data/lol win predict/lol-prediction/lol.x_train.csv')

# %%
ytrain_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180000 entries, 0 to 179999
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  180000 non-null  int64
#  1   blueWins    180000 non-null  int64
# dtypes: int64(2)
# memory usage: 2.7 MB

# %%
xtrain_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180000 entries, 0 to 179999
# Data columns (total 49 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Unnamed: 0               180000 non-null  int64
#  1   gameDuraton              180000 non-null  int64
#  2   blueFirstBlood           180000 non-null  int64
#  3   blueFirstTower           180000 non-null  int64
#  4   blueFirstBaron           180000 non-null  int64
#  5   blueFirstDragon          180000 non-null  int64
#  6   blueFirstInhibitor       180000 non-null  int64
#  7   blueDragonKills          180000 non-null  int64
#  8   blueBaronKills           180000 non-null  int64
#  9   blueTowerKills           180000 non-null  int64
#  10  blueInhibitorKills       180000 non-null  int64
#  11  blueWardPlaced           180000 non-null  int64
#  12  blueWardkills            180000 non-null  int64
#  13  blueKills                180000 non-null  int64
#  14  blueDeath                180000 non-null  int64
#  15  blueAssist               180000 non-null  int64
#  16  blueChampionDamageDealt  180000 non-null  int64
#  17  blueTotalGold            180000 non-null  int64
#  18  blueTotalMinionKills     180000 non-null  int64
#  19  blueTotalLevel           180000 non-null  int64
#  20  blueAvgLevel             180000 non-null  float64
#  21  blueJungleMinionKills    180000 non-null  int64
#  22  blueKillingSpree         180000 non-null  int64
#  23  blueTotalHeal            180000 non-null  int64
#  24  blueObjectDamageDealt    180000 non-null  int64
#  25  redFirstBaron            180000 non-null  int64
#  26  redFirstDragon           180000 non-null  int64
#  27  redFirstInhibitor        180000 non-null  int64
#  28  redDragonKills           180000 non-null  int64
#  29  redBaronKills            180000 non-null  int64
#  30  redTowerKills            180000 non-null  int64
#  31  redInhibitorKills        180000 non-null  int64
#  32  redWardPlaced            180000 non-null  int64
#  33  redWardkills             180000 non-null  int64
#  34  redKills                 180000 non-null  int64
#  35  redDeath                 180000 non-null  int64
#  36  redAssist                180000 non-null  int64
#  37  redChampionDamageDealt   180000 non-null  int64
#  38  redTotalGold             180000 non-null  int64
#  39  redTotalMinionKills      180000 non-null  int64
#  40  redTotalLevel            180000 non-null  int64
#  41  redAvgLevel              180000 non-null  float64
#  42  redJungleMinionKills     180000 non-null  int64
#  43  redKillingSpree          180000 non-null  int64
#  44  redTotalHeal             180000 non-null  int64
#  45  redObjectDamageDealt     180000 non-null  int64
#  46  Rank_Challenger          180000 non-null  int64
#  47  Rank_GrandMaster         180000 non-null  int64
#  48  Rank_Master              180000 non-null  int64
# dtypes: float64(2), int64(47)
# memory usage: 67.3 MB

# %%
df = pd.merge(xtrain_data, ytrain_data, on='Unnamed: 0', how='inner')

# %%
df.head()
# Out:
#    Unnamed: 0  gameDuraton  ...  Rank_Master  blueWins
# 0           0         1906  ...            0         1
# 1           1         1454  ...            1         1
# 2           2         1449  ...            0         0
# 3           3         1832  ...            1         0
# 4           4         1098  ...            1         0
#
# [5 rows x 50 columns]

# %% [markdown]
# #1. PREPROCESSING

# %% [markdown]
# 1.1 drop Unnamed: 0 and gameDuration

# %%
df.drop(columns = 'Unnamed: 0', inplace = True)
df.drop(columns = 'gameDuraton', inplace = True)

# %%
df.head()
# Out:
#    blueFirstBlood  blueFirstTower  ...  Rank_Master  blueWins
# 0               0               1  ...            0         1
# 1               0               1  ...            1         1
# 2               1               1  ...            0         0
# 3               0               0  ...            1         0
# 4               0               0  ...            1         0
#
# [5 rows x 48 columns]

# %% [markdown]
# 1.2 drop
#
# redFirstBaron,
#
# redFirstDragon,
#
# redFirstInhibitor
#
# the reason for dropping those columns is that if the blue team has first Baron, first Dragon, or first Inhibitor, the red team does not have it.
#
# hence the columns mentioned above do not provide more information to our model.
#
# hence they are dropped.

# %%
#df.drop(['redFirstBaron', 'redFirstDragon', 'redFirstInhibitor'], axis = 1, inplace = True)

# %%
#df.describe()

# %% [markdown]
# 1.3 Rank_Challenger, Rank_GrandMaster, Rank_Master
#
# about 54% of the games are Rank_Master
#
# about 33% of the games are Rank_GrandMaster
#
# about 13% of the games are Rank_Challenger
#
# In League of Legends, of all competitive ranked players
#
# .12% are Master tier
#
# .029% are Grandmaster tier
#
# .013% are Challenger tier
# source: https://support-leagueoflegends.riotgames.com/hc/en-us/articles/4405776545427-Master-Grandmaster-and-Challenger-The-Apex-Tiers
#
# in our data, 13% of 180,000 data points is 23,400
#
# which i believe is enough for this project
#
# hence, i'm going to drop the data points for
#
# Rank_Master and Rank_GrandMaster
#
# Advantages of doing so:
# 1. less data that will result in a faster calculation
# 2. the model will be specifically focusing on Rank_Challenger games

# %%
df_Challenger = df[df.Rank_Challenger == 1]

# %%
df_Challenger.head()
# Out:
#     blueFirstBlood  blueFirstTower  ...  Rank_Master  blueWins
# 8                1               1  ...            0         1
# 10               1               0  ...            0         0
# 13               0               0  ...            0         1
# 21               0               0  ...            0         1
# 22               1               0  ...            0         1
#
# [5 rows x 48 columns]

# %%
# since i've created df_Challenger that's only for Rank_Challenger games
# i can drop the columns Rank_Challenger, Rank_GrandMaster, Rank_Master

df_Challenger.drop(['Rank_Challenger', 'Rank_GrandMaster', 'Rank_Master'], axis = 1, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_Challenger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24195 entries, 8 to 179994
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   blueFirstBlood           24195 non-null  int64
#  1   blueFirstTower           24195 non-null  int64
#  2   blueFirstBaron           24195 non-null  int64
#  3   blueFirstDragon          24195 non-null  int64
#  4   blueFirstInhibitor       24195 non-null  int64
#  5   blueDragonKills          24195 non-null  int64
#  6   blueBaronKills           24195 non-null  int64
#  7   blueTowerKills           24195 non-null  int64
#  8   blueInhibitorKills       24195 non-null  int64
#  9   blueWardPlaced           24195 non-null  int64
#  10  blueWardkills            24195 non-null  int64
#  11  blueKills                24195 non-null  int64
#  12  blueDeath                24195 non-null  int64
#  13  blueAssist               24195 non-null  int64
#  14  blueChampionDamageDealt  24195 non-null  int64
#  15  blueTotalGold            24195 non-null  int64
#  16  blueTotalMinionKills     24195 non-null  int64
#  17  blueTotalLevel           24195 non-null  int64
#  18  blueAvgLevel             24195 non-null  float64
#  19  blueJungleMinionKills    24195 non-null  int64
#  20  blueKillingSpree         24195 non-null  int64
#  21  blueTotalHeal            24195 non-null  int64
#  22  blueObjectDamageDealt    24195 non-null  int64
#  23  redFirstBaron            24195 non-null  int64
#  24  redFirstDragon           24195 non-null  int64
#  25  redFirstInhibitor        24195 non-null  int64
#  26  redDragonKills           24195 non-null  int64
#  27  redBaronKills            24195 non-null  int64
#  28  redTowerKills            24195 non-null  int64
#  29  redInhibitorKills        24195 non-null  int64
#  30  redWardPlaced            24195 non-null  int64
#  31  redWardkills             24195 non-null  int64
#  32  redKills                 24195 non-null  int64
#  33  redDeath                 24195 non-null  int64
#  34  redAssist                24195 non-null  int64
#  35  redChampionDamageDealt   24195 non-null  int64
#  36  redTotalGold             24195 non-null  int64
#  37  redTotalMinionKills      24195 non-null  int64
#  38  redTotalLevel            24195 non-null  int64
#  39  redAvgLevel              24195 non-null  float64
#  40  redJungleMinionKills     24195 non-null  int64
#  41  redKillingSpree          24195 non-null  int64
#  42  redTotalHeal             24195 non-null  int64
#  43  redObjectDamageDealt     24195 non-null  int64
#  44  blueWins                 24195 non-null  int64
# dtypes: float64(2), int64(43)
# memory usage: 8.5 MB

# %%
# drop duplicates
df_Challenger.drop_duplicates()
# Out:
#         blueFirstBlood  blueFirstTower  ...  redObjectDamageDealt  blueWins
# 8                    1               1  ...                 17949         1
# 10                   1               0  ...                 39714         0
# 13                   0               0  ...                 72472         1
# 21                   0               0  ...                 23314         1
# 22                   1               0  ...                 42240         1
# ...                ...             ...  ...                   ...       ...
# 179947               1               0  ...                 32282         1
# 179961               0               1  ...                 53720         0
# 179975               0               0  ...                 31237         0
# 179980               0               1  ...                 22116         1
# 179994               0               0  ...                  4277         1
#
# [24152 rows x 45 columns]

# %%
df_Challenger.describe()
# Out:
#        blueFirstBlood  blueFirstTower  ...  redObjectDamageDealt      blueWins
# count    24195.000000    24195.000000  ...          24195.000000  24195.000000
# mean         0.504071        0.525770  ...          37589.471378      0.501095
# std          0.499994        0.499346  ...          26479.789833      0.500009
# min          0.000000        0.000000  ...              0.000000      0.000000
# 25%          0.000000        0.000000  ...          14481.000000      0.000000
# 50%          1.000000        1.000000  ...          33279.000000      1.000000
# 75%          1.000000        1.000000  ...          57692.500000      1.000000
# max          1.000000        1.000000  ...         151419.000000      1.000000
#
# [8 rows x 45 columns]

# %%
# from .describe() i can tell the data is balanced
# below is the value_counts()
df_Challenger['blueWins'].value_counts()
# Out:
# 1    12124
# 0    12071
# Name: blueWins, dtype: int64

# %% [markdown]
# 1.4 blueTotalLevel
#
# in League of Legends, the max level a player could get in every game is 18 in most game modes
#
# there are 5 players on either blue or red side
#
# that the max level for each team is 18x5=90
#
# from the .describe() above we can see the max for blueTotalLevel is 123
#
# hence i'm going to drop the rows where the blueTotalLevel is more than 90
#
# then i'm going to check if the processed data set has redTotalLevel more than 90 and drop those rows as well.

# %%
df_Challenger = df_Challenger[df_Challenger.blueTotalLevel <= 90]

# %%
df_Challenger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24100 entries, 8 to 179994
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   blueFirstBlood           24100 non-null  int64
#  1   blueFirstTower           24100 non-null  int64
#  2   blueFirstBaron           24100 non-null  int64
#  3   blueFirstDragon          24100 non-null  int64
#  4   blueFirstInhibitor       24100 non-null  int64
#  5   blueDragonKills          24100 non-null  int64
#  6   blueBaronKills           24100 non-null  int64
#  7   blueTowerKills           24100 non-null  int64
#  8   blueInhibitorKills       24100 non-null  int64
#  9   blueWardPlaced           24100 non-null  int64
#  10  blueWardkills            24100 non-null  int64
#  11  blueKills                24100 non-null  int64
#  12  blueDeath                24100 non-null  int64
#  13  blueAssist               24100 non-null  int64
#  14  blueChampionDamageDealt  24100 non-null  int64
#  15  blueTotalGold            24100 non-null  int64
#  16  blueTotalMinionKills     24100 non-null  int64
#  17  blueTotalLevel           24100 non-null  int64
#  18  blueAvgLevel             24100 non-null  float64
#  19  blueJungleMinionKills    24100 non-null  int64
#  20  blueKillingSpree         24100 non-null  int64
#  21  blueTotalHeal            24100 non-null  int64
#  22  blueObjectDamageDealt    24100 non-null  int64
#  23  redFirstBaron            24100 non-null  int64
#  24  redFirstDragon           24100 non-null  int64
#  25  redFirstInhibitor        24100 non-null  int64
#  26  redDragonKills           24100 non-null  int64
#  27  redBaronKills            24100 non-null  int64
#  28  redTowerKills            24100 non-null  int64
#  29  redInhibitorKills        24100 non-null  int64
#  30  redWardPlaced            24100 non-null  int64
#  31  redWardkills             24100 non-null  int64
#  32  redKills                 24100 non-null  int64
#  33  redDeath                 24100 non-null  int64
#  34  redAssist                24100 non-null  int64
#  35  redChampionDamageDealt   24100 non-null  int64
#  36  redTotalGold             24100 non-null  int64
#  37  redTotalMinionKills      24100 non-null  int64
#  38  redTotalLevel            24100 non-null  int64
#  39  redAvgLevel              24100 non-null  float64
#  40  redJungleMinionKills     24100 non-null  int64
#  41  redKillingSpree          24100 non-null  int64
#  42  redTotalHeal             24100 non-null  int64
#  43  redObjectDamageDealt     24100 non-null  int64
#  44  blueWins                 24100 non-null  int64
# dtypes: float64(2), int64(43)
# memory usage: 8.5 MB

# %%
df_Challenger.describe()
# Out:
#        blueFirstBlood  blueFirstTower  ...  redObjectDamageDealt      blueWins
# count    24100.000000    24100.000000  ...          24100.000000  24100.000000
# mean         0.504232        0.526058  ...          37443.032863      0.500705
# std          0.499992        0.499331  ...          26341.360559      0.500010
# min          0.000000        0.000000  ...              0.000000      0.000000
# 25%          0.000000        0.000000  ...          14396.750000      0.000000
# 50%          1.000000        1.000000  ...          33122.000000      1.000000
# 75%          1.000000        1.000000  ...          57561.000000      1.000000
# max          1.000000        1.000000  ...         151419.000000      1.000000
#
# [8 rows x 45 columns]

# %% [markdown]
# 1.5 redTotalLevel
#
# i see that the max for redTotalLevel is 108
# repeat the same steps we did for blueTotalLevel

# %%
df_Challenger = df_Challenger[df_Challenger.redTotalLevel <= 90]
df_Challenger.describe()
# Out:
#        blueFirstBlood  blueFirstTower  ...  redObjectDamageDealt      blueWins
# count    24075.000000    24075.000000  ...          24075.000000  24075.000000
# mean         0.504382        0.526106  ...          37398.415202      0.501101
# std          0.499991        0.499328  ...          26305.846853      0.500009
# min          0.000000        0.000000  ...              0.000000      0.000000
# 25%          0.000000        0.000000  ...          14381.000000      0.000000
# 50%          1.000000        1.000000  ...          33097.000000      1.000000
# 75%          1.000000        1.000000  ...          57514.500000      1.000000
# max          1.000000        1.000000  ...         151419.000000      1.000000
#
# [8 rows x 45 columns]

# %%
df_Challenger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24075 entries, 8 to 179994
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   blueFirstBlood           24075 non-null  int64
#  1   blueFirstTower           24075 non-null  int64
#  2   blueFirstBaron           24075 non-null  int64
#  3   blueFirstDragon          24075 non-null  int64
#  4   blueFirstInhibitor       24075 non-null  int64
#  5   blueDragonKills          24075 non-null  int64
#  6   blueBaronKills           24075 non-null  int64
#  7   blueTowerKills           24075 non-null  int64
#  8   blueInhibitorKills       24075 non-null  int64
#  9   blueWardPlaced           24075 non-null  int64
#  10  blueWardkills            24075 non-null  int64
#  11  blueKills                24075 non-null  int64
#  12  blueDeath                24075 non-null  int64
#  13  blueAssist               24075 non-null  int64
#  14  blueChampionDamageDealt  24075 non-null  int64
#  15  blueTotalGold            24075 non-null  int64
#  16  blueTotalMinionKills     24075 non-null  int64
#  17  blueTotalLevel           24075 non-null  int64
#  18  blueAvgLevel             24075 non-null  float64
#  19  blueJungleMinionKills    24075 non-null  int64
#  20  blueKillingSpree         24075 non-null  int64
#  21  blueTotalHeal            24075 non-null  int64
#  22  blueObjectDamageDealt    24075 non-null  int64
#  23  redFirstBaron            24075 non-null  int64
#  24  redFirstDragon           24075 non-null  int64
#  25  redFirstInhibitor        24075 non-null  int64
#  26  redDragonKills           24075 non-null  int64
#  27  redBaronKills            24075 non-null  int64
#  28  redTowerKills            24075 non-null  int64
#  29  redInhibitorKills        24075 non-null  int64
#  30  redWardPlaced            24075 non-null  int64
#  31  redWardkills             24075 non-null  int64
#  32  redKills                 24075 non-null  int64
#  33  redDeath                 24075 non-null  int64
#  34  redAssist                24075 non-null  int64
#  35  redChampionDamageDealt   24075 non-null  int64
#  36  redTotalGold             24075 non-null  int64
#  37  redTotalMinionKills      24075 non-null  int64
#  38  redTotalLevel            24075 non-null  int64
#  39  redAvgLevel              24075 non-null  float64
#  40  redJungleMinionKills     24075 non-null  int64
#  41  redKillingSpree          24075 non-null  int64
#  42  redTotalHeal             24075 non-null  int64
#  43  redObjectDamageDealt     24075 non-null  int64
#  44  blueWins                 24075 non-null  int64
# dtypes: float64(2), int64(43)
# memory usage: 8.4 MB

# %% [markdown]
# 1.6 Remove Outliers

# %%
# blueWardPlaced 
df_Challenger = df_Challenger[df_Challenger.blueWardPlaced < 100]
df_Challenger.describe()
# Out:
#        blueFirstBlood  blueFirstTower  ...  redObjectDamageDealt      blueWins
# count    21773.000000    21773.000000  ...          21773.000000  21773.000000
# mean         0.506131        0.524365  ...          34563.235797      0.499058
# std          0.499974        0.499417  ...          24848.656049      0.500011
# min          0.000000        0.000000  ...              0.000000      0.000000
# 25%          0.000000        0.000000  ...          12657.000000      0.000000
# 50%          1.000000        1.000000  ...          29758.000000      0.000000
# 75%          1.000000        1.000000  ...          53849.000000      1.000000
# max          1.000000        1.000000  ...         148813.000000      1.000000
#
# [8 rows x 45 columns]

# %%
# blueKill
df_Challenger = df_Challenger[df_Challenger.blueKills < 40]
df_Challenger.describe()
# Out:
#        blueFirstBlood  blueFirstTower  ...  redObjectDamageDealt      blueWins
# count    19566.000000    19566.000000  ...          19566.000000  19566.000000
# mean         0.500664        0.513033  ...          35969.763876      0.471328
# std          0.500012        0.499843  ...          24651.340103      0.499190
# min          0.000000        0.000000  ...              0.000000      0.000000
# 25%          0.000000        0.000000  ...          14761.750000      0.000000
# 50%          1.000000        1.000000  ...          31688.500000      0.000000
# 75%          1.000000        1.000000  ...          55199.500000      1.000000
# max          1.000000        1.000000  ...         148813.000000      1.000000
#
# [8 rows x 45 columns]

# %%
# blueDeath
df_Challenger = df_Challenger[df_Challenger.blueDeath < 40]
df_Challenger.describe()
# Out:
#        blueFirstBlood  blueFirstTower  ...  redObjectDamageDealt      blueWins
# count    18360.000000    18360.000000  ...          18360.000000  18360.000000
# mean         0.510131        0.528486  ...          34914.783497      0.499292
# std          0.499911        0.499201  ...          23989.983356      0.500013
# min          0.000000        0.000000  ...              0.000000      0.000000
# 25%          0.000000        0.000000  ...          14679.000000      0.000000
# 50%          1.000000        1.000000  ...          30471.000000      0.000000
# 75%          1.000000        1.000000  ...          53330.000000      1.000000
# max          1.000000        1.000000  ...         148813.000000      1.000000
#
# [8 rows x 45 columns]

# %% [markdown]
# summary: from 180,000 rows to 18,360 rows we have cleaned our data.

# %% [markdown]
# #2. UNIVARIATE VISUALS

# %% [markdown]
# 2.1  corr

# %%
df_Challenger.head()
# Out:
#     blueFirstBlood  blueFirstTower  ...  redObjectDamageDealt  blueWins
# 8                1               1  ...                 17949         1
# 10               1               0  ...                 39714         0
# 21               0               0  ...                 23314         1
# 22               1               0  ...                 42240         1
# 32               1               1  ...                 23356         1
#
# [5 rows x 45 columns]

# %%
df_Challenger.reset_index(drop=True, inplace=True)
df_Challenger.head()
# Out:
#    blueFirstBlood  blueFirstTower  ...  redObjectDamageDealt  blueWins
# 0               1               1  ...                 17949         1
# 1               1               0  ...                 39714         0
# 2               0               0  ...                 23314         1
# 3               1               0  ...                 42240         1
# 4               1               1  ...                 23356         1
#
# [5 rows x 45 columns]

# %%
df_Challenger.describe()
# Out:
#        blueFirstBlood  blueFirstTower  ...  redObjectDamageDealt      blueWins
# count    18360.000000    18360.000000  ...          18360.000000  18360.000000
# mean         0.510131        0.528486  ...          34914.783497      0.499292
# std          0.499911        0.499201  ...          23989.983356      0.500013
# min          0.000000        0.000000  ...              0.000000      0.000000
# 25%          0.000000        0.000000  ...          14679.000000      0.000000
# 50%          1.000000        1.000000  ...          30471.000000      0.000000
# 75%          1.000000        1.000000  ...          53330.000000      1.000000
# max          1.000000        1.000000  ...         148813.000000      1.000000
#
# [8 rows x 45 columns]

# %%
df_Challenger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18360 entries, 0 to 18359
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   blueFirstBlood           18360 non-null  int64
#  1   blueFirstTower           18360 non-null  int64
#  2   blueFirstBaron           18360 non-null  int64
#  3   blueFirstDragon          18360 non-null  int64
#  4   blueFirstInhibitor       18360 non-null  int64
#  5   blueDragonKills          18360 non-null  int64
#  6   blueBaronKills           18360 non-null  int64
#  7   blueTowerKills           18360 non-null  int64
#  8   blueInhibitorKills       18360 non-null  int64
#  9   blueWardPlaced           18360 non-null  int64
#  10  blueWardkills            18360 non-null  int64
#  11  blueKills                18360 non-null  int64
#  12  blueDeath                18360 non-null  int64
#  13  blueAssist               18360 non-null  int64
#  14  blueChampionDamageDealt  18360 non-null  int64
#  15  blueTotalGold            18360 non-null  int64
#  16  blueTotalMinionKills     18360 non-null  int64
#  17  blueTotalLevel           18360 non-null  int64
#  18  blueAvgLevel             18360 non-null  float64
#  19  blueJungleMinionKills    18360 non-null  int64
#  20  blueKillingSpree         18360 non-null  int64
#  21  blueTotalHeal            18360 non-null  int64
#  22  blueObjectDamageDealt    18360 non-null  int64
#  23  redFirstBaron            18360 non-null  int64
#  24  redFirstDragon           18360 non-null  int64
#  25  redFirstInhibitor        18360 non-null  int64
#  26  redDragonKills           18360 non-null  int64
#  27  redBaronKills            18360 non-null  int64
#  28  redTowerKills            18360 non-null  int64
#  29  redInhibitorKills        18360 non-null  int64
#  30  redWardPlaced            18360 non-null  int64
#  31  redWardkills             18360 non-null  int64
#  32  redKills                 18360 non-null  int64
#  33  redDeath                 18360 non-null  int64
#  34  redAssist                18360 non-null  int64
#  35  redChampionDamageDealt   18360 non-null  int64
#  36  redTotalGold             18360 non-null  int64
#  37  redTotalMinionKills      18360 non-null  int64
#  38  redTotalLevel            18360 non-null  int64
#  39  redAvgLevel              18360 non-null  float64
#  40  redJungleMinionKills     18360 non-null  int64
#  41  redKillingSpree          18360 non-null  int64
#  42  redTotalHeal             18360 non-null  int64
#  43  redObjectDamageDealt     18360 non-null  int64
#  44  blueWins                 18360 non-null  int64
# dtypes: float64(2), int64(43)
# memory usage: 6.3 MB

# %%
import seaborn as sns
corr = df_Challenger.corr()
sns.heatmap(corr, cmap = 'YlGn');

# %%
 sig_corr = corr.loc[abs(corr['blueWins']) >= 0.5]
 sig_corr.index
 for i in sig_corr.index:
     print('The absolute correlation coefficient of Blue Team Wins vs.', i, 'is', abs(sig_corr.loc[i]['blueWins']))
# Out:
# The absolute correlation coefficient of Blue Team Wins vs. blueFirstTower is 0.5211891565593849
# The absolute correlation coefficient of Blue Team Wins vs. blueFirstInhibitor is 0.6412787999765784
# The absolute correlation coefficient of Blue Team Wins vs. blueDragonKills is 0.5318839413111451
# The absolute correlation coefficient of Blue Team Wins vs. blueTowerKills is 0.7327588520385552
# The absolute correlation coefficient of Blue Team Wins vs. blueInhibitorKills is 0.5622381897370853
# The absolute correlation coefficient of Blue Team Wins vs. blueKills is 0.6163453691668153
# The absolute correlation coefficient of Blue Team Wins vs. blueDeath is 0.6075062767145276
# The absolute correlation coefficient of Blue Team Wins vs. blueAssist is 0.5261363918412413
# The absolute correlation coefficient of Blue Team Wins vs. blueKillingSpree is 0.564462067550781
# The absolute correlation coefficient of Blue Team Wins vs. blueObjectDamageDealt is 0.6063150497098887
# The absolute correlation coefficient of Blue Team Wins vs. redFirstInhibitor is 0.6280800703396792
# The absolute correlation coefficient of Blue Team Wins vs. redDragonKills is 0.5308540397017671
# The absolute correlation coefficient of Blue Team Wins vs. redTowerKills is 0.7337238400581659
# The absolute correlation coefficient of Blue Team Wins vs. redInhibitorKills is 0.5608474232324392
# The absolute correlation coefficient of Blue Team Wins vs. redKills is 0.6087807970239093
# The absolute correlation coefficient of Blue Team Wins vs. redDeath is 0.6148981561179655
# The absolute correlation coefficient of Blue Team Wins vs. redAssist is 0.516969570128851
# The absolute correlation coefficient of Blue Team Wins vs. redKillingSpree is 0.5564538179881794
# The absolute correlation coefficient of Blue Team Wins vs. redObjectDamageDealt is 0.6302138260303016
# The absolute correlation coefficient of Blue Team Wins vs. blueWins is 1.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-deep')

# %%
blue_tower_kills = df_Challenger['blueTowerKills']
red_tower_kills = df_Challenger['redTowerKills']

plt.hist(blue_tower_kills, bins = 10, alpha = .3, label='Blue Team Tower Kills');
plt.hist(red_tower_kills, bins = 10, alpha = .9, label='Red Team Tower Kills');
plt.legend(loc='upper right');
plt.xlabel('Tower Kills');
plt.ylabel('Count');

# %%
blue_baron_kills = df_Challenger['blueBaronKills']
red_baron_kills = df_Challenger['redBaronKills']

plt.hist(blue_baron_kills, bins = 5, alpha = 1, label='Blue Team Baron Kills');
plt.hist(red_baron_kills, bins = 5, alpha = .9, label='Red Team Baron Kills');
plt.legend(loc='upper right');
plt.xlabel('Baron Kills');
plt.ylabel('Count');

# %%
blue_total_heal = df_Challenger.loc[:, 'blueTotalHeal']
red_total_heal = df_Challenger.loc[:, 'redTotalHeal']
fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (10,5))
boxplots = axes.boxplot([blue_total_gold, red_total_gold],
                        notch = True,
                        labels = ['Total Heal of Blue Team', 'Total Heal of Red Team'],
                        patch_artist = True,
                        widths = 0.5,
                        medianprops = dict(linestyle='-', linewidth = 2, color='black'),
                        boxprops = dict(linestyle='--', linewidth = 2, color='white', facecolor='blue', alpha = 0.5)
                        );
boxplot1 = boxplots['boxes'][0];
boxplot1.set_facecolor('yellow');
plt.ylabel('Total Heal of Each Team', fontsize = 20);

# %%
blue_team_wins = df_Challenger.loc[df_Challenger['blueWins'] == 1, 'blueTowerKills']
blue_team_loses = df_Challenger.loc[df_Challenger['blueWins'] == 0, 'blueTowerKills']

fig, axes = plt.subplots(nrows=1, ncols=1, figsize= (10,5))
boxplots = axes.boxplot([blue_team_wins, blue_team_loses],
                        notch = True,
                        labels = ['blue wins', 'blue loses'],
                        patch_artist = True,
                        medianprops = dict(linestyle='-', linewidth=3, color='Yellow'),
                        boxprops = dict(linestyle='---', linewidth=10, color='purple', facecolor = 'green', alpha = 0.9)
                        );
boxplot1 = boxplots['boxes'][0]
boxplot1.set_facecolor('red')
plt.xlabel('Blue Team Wins or Loses', fontsize=20);
plt.ylabel('Blue Team Tower Kills', fontsize = 20);
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
